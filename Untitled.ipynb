# %% [markdown]
# # univariate selection

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
data=pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X= data.iloc[: ,0:20]
y=data.iloc[:,-1]

# %%
# apply selctk best ,top 10 features
best_features =SelectKBest(score_func=chi2,k=10)

# %%
fit =best_features.fit(X,y)

# %%
fit.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
dfscores=pd.DataFrame(fit.scores_)
dfcolumns =pd.DataFrame(X.columns)

# %%
fetauresscores=pd.concat([dfcolumns,dfscores],axis=1)

# %%
fetauresscores.columns=["features","score"]

# %%
fetauresscores.sort_values(by='score',ascending=False).head(10)
# Out:
#          features          score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# # Features importance

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
model =RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
model.feature_importances_   #just like the value are best on percentage ...i.e ,the 0.07683 % of the 1st features contributing
# Out:
# array([0.07683011, 0.00679865, 0.02678203, 0.00640907, 0.02501881,
#        0.00628573, 0.03547306, 0.02478568, 0.03840064, 0.02315423,
#        0.02904183, 0.05455548, 0.05761926, 0.48391021, 0.02770124,
#        0.02889123, 0.02938643, 0.00551238, 0.00681368, 0.00663024])

# %%
featuresimportance=pd.DataFrame(model.feature_importances_ ,index=X.columns,columns=["importance"])

# %%
featuresimportance =featuresimportance.sort_values(by="importance",ascending=False)

# %%
featuresimportance
# Out:
#                importance
# ram              0.483910
# battery_power    0.076830
# px_width         0.057619
# px_height        0.054555
# mobile_wt        0.038401
# int_memory       0.035473
# talk_time        0.029386
# pc               0.029042
# sc_w             0.028891
# sc_h             0.027701
# clock_speed      0.026782
# fc               0.025019
# m_dep            0.024786
# n_cores          0.023154
# touch_screen     0.006814
# blue             0.006799
# wifi             0.006630
# dual_sim         0.006409
# four_g           0.006286
# three_g          0.005512

# %%
plt.figure(figsize=(20,6))
plt.bar(featuresimportance.index,featuresimportance['importance'])
plt.show()

# %% [markdown]
# ## correaltion matrix

# %%
import seaborn as sns
datacorr=data.corr()

# %%
datacorr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(20,6))
sns.heatmap(datacorr,annot=True)
plt.show()

# %% [markdown]
# # check the model performance

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
rfc=RandomForestClassifier()

# %%
scores= cross_val_score(rfc ,X, y,cv=10)

# %%
scores.mean()
# Out:
# 0.884

# %%
tenfeatures=fetauresscores.sort_values(by='score',ascending=False).head(5)['features'].values

# %%
tenfeatures
# Out:
# array(['ram', 'px_height', 'battery_power', 'px_width', 'mobile_wt'],
#       dtype=object)

# %%
X[tenfeatures]
# Out:
#        ram  px_height  battery_power  px_width  mobile_wt
# 0     2549         20            842       756        188
# 1     2631        905           1021      1988        136
# 2     2603       1263            563      1716        145
# 3     2769       1216            615      1786        131
# 4     1411       1208           1821      1212        141
# ...    ...        ...            ...       ...        ...
# 1995   668       1222            794      1890        106
# 1996  2032        915           1965      1965        187
# 1997  3057        868           1911      1632        108
# 1998   869        336           1512       670        145
# 1999  3919        483            510       754        168
#
# [2000 rows x 5 columns]

# %%
scores_new=cross_val_score(rfc,X[tenfeatures],y,cv=10)

# %%
scores_new.mean()
# Out:
# 0.9139999999999999
